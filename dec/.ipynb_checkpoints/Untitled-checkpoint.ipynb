# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
listings = pd.read_csv('./listings.csv')
listings.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   44077   https://www.airbnb.com/rooms/44077  20220911231053   2022-09-12
# 1   85156   https://www.airbnb.com/rooms/85156  20220911231053   2022-09-12
# 2  159889  https://www.airbnb.com/rooms/159889  20220911231053   2022-09-12
# 3  162809  https://www.airbnb.com/rooms/162809  20220911231053   2022-09-11
# 4  165828  https://www.airbnb.com/rooms/165828  20220911231053   2022-09-11
#
#         source                                          name  \
# 0  city scrape           cosy comfortable Irish cottage twin
# 1  city scrape  Cosy Comfortable Irish Cottage  1 Double Bed
# 2  city scrape                          Friendly Single Room
# 3  city scrape            5.5 miles south of Dublin City :^)
# 4  city scrape                Pádraig Pearse apt. Kilmainham
#
#                                          description  \
# 0  Our house was built in 1937 when there was ple...
# ...

# %%
listings.rename(columns={'id':'listing_id'}, inplace = True)
listings
# Out:
#               listing_id                                      listing_url  \
# 0                  44077               https://www.airbnb.com/rooms/44077
# 1                  85156               https://www.airbnb.com/rooms/85156
# 2                 159889              https://www.airbnb.com/rooms/159889
# 3                 162809              https://www.airbnb.com/rooms/162809
# 4                 165828              https://www.airbnb.com/rooms/165828
# ...                  ...                                              ...
# 7561  712909401324393615  https://www.airbnb.com/rooms/712909401324393615
# 7562  712914322433199115  https://www.airbnb.com/rooms/712914322433199115
# 7563  712914393022526732  https://www.airbnb.com/rooms/712914393022526732
# 7564  712966369602352444  https://www.airbnb.com/rooms/712966369602352444
# 7565  713034176403340330  https://www.airbnb.com/rooms/713034176403340330
#
#            scrape_id last_scraped       source  \
# ...

# %%
reviews = pd.read_csv('./reviews.csv')
reviews.head()
# Out:
#    listing_id      id        date  reviewer_id         reviewer_name  \
# 0       44077  203703  2011-03-20       393348             Christian
# 1       44077  211369  2011-03-28       444004               Solidea
# 2       44077  234215  2011-04-21       465058  Michael And Isabelle
# 3       44077  261843  2011-05-13       490005                Weston
# 4       44077  268148  2011-05-17       520460               Barbara
#
#                                             comments
# 0  We enjoyed our stay very much. The room was co...
# 1  We have been here 4 nights. Stay in a home is ...
# 2  Teresa and Hughie were great hosts. They were ...
# 3  No surprises, was as described.  Very gracious...
# 4  Teresa was a lovely hostess, and we had a deli...

# %%
df = listings.join(reviews.set_index('listing_id'), on='listing_id', lsuffix= '_listing')

# %%
df.head()
# Out:
#    listing_id                         listing_url       scrape_id  \
# 0       44077  https://www.airbnb.com/rooms/44077  20220911231053
# 0       44077  https://www.airbnb.com/rooms/44077  20220911231053
# 0       44077  https://www.airbnb.com/rooms/44077  20220911231053
# 0       44077  https://www.airbnb.com/rooms/44077  20220911231053
# 0       44077  https://www.airbnb.com/rooms/44077  20220911231053
#
#   last_scraped       source                                 name  \
# 0   2022-09-12  city scrape  cosy comfortable Irish cottage twin
# 0   2022-09-12  city scrape  cosy comfortable Irish cottage twin
# 0   2022-09-12  city scrape  cosy comfortable Irish cottage twin
# 0   2022-09-12  city scrape  cosy comfortable Irish cottage twin
# 0   2022-09-12  city scrape  cosy comfortable Irish cottage twin
#
#                                          description  \
# 0  Our house was built in 1937 when there was ple...
# 0  Our house was built in 1937 when there was ple...
# ...

# %%
df.columns
# Out:
# Index(['listing_id', 'listing_url', 'scrape_id', 'last_scraped', 'source',
#        'name', 'description', 'neighborhood_overview', 'picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
ys = df.filter(regex='^review_scores.*')
ys.head()
# Out:
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.78                    4.83                       4.74
# 0                  4.78                    4.83                       4.74
# 0                  4.78                    4.83                       4.74
# 0                  4.78                    4.83                       4.74
# 0                  4.78                    4.83                       4.74
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.93                         4.93                    4.66
# 0                   4.93                         4.93                    4.66
# 0                   4.93                         4.93                    4.66
# 0                   4.93                         4.93                    4.66
# 0                   4.93                         4.93                    4.66
#
#    review_scores_value
# ...

# %%
for col in df.columns:
    print(df[col])
# Out:
# 0                    44077
# 0                    44077
# 0                    44077
# 0                    44077
# 0                    44077
#                ...
# 7561    712909401324393615
# 7562    712914322433199115
# 7563    712914393022526732
# 7564    712966369602352444
# 7565    713034176403340330
# Name: listing_id, Length: 244540, dtype: int64
# 0                    https://www.airbnb.com/rooms/44077
# 0                    https://www.airbnb.com/rooms/44077
# 0                    https://www.airbnb.com/rooms/44077
# 0                    https://www.airbnb.com/rooms/44077
# 0                    https://www.airbnb.com/rooms/44077
#                              ...
# 7561    https://www.airbnb.com/rooms/712909401324393615
# 7562    https://www.airbnb.com/rooms/712914322433199115
# 7563    https://www.airbnb.com/rooms/712914393022526732
# 7564    https://www.airbnb.com/rooms/712966369602352444
# 7565    https://www.airbnb.com/rooms/713034176403340330
# ...

# %%
#model building

# %%
import torch

class regg(torch.nn.Module):
    
    def __init__(self, inpp , outt):
        super().__init__()
        self.linear1 = torch.nn.Linear(inpp, 20)
        self.activation = torch.nn.ReLU()
        self.linear2 = torch.nn.Linear(20 , outt)
        self.activation2 = torch.nn.ReLU()
    
    
    def forward(self):
        x = self.linear1(x)
        x = self.activation(x)
        x = self.linear2(x)
        x = self.softmax(x)
        return x

# %%
def trainn(epocs, x, y, model, optimizer , loss_fn):
    error_trace = []
    
    for epoch in epochs:
        outputs = model.forward(x)

        loss = loss_fn(outputs, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        error_trace += loss.item()
        if epoch == 1 or epoch % 10 == 0:
                print('{} Epoch {}, Training loss {}'.format(
                    datetime.datetime.now(), epoch,
                    error_trace[-1]))

# %%
model = regg(30 , 1)
